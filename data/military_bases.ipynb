# %% [markdown]
# # Web Scraping Military Bases from Wikipedia

# %% [markdown]
# ### Set up

# %%
import requests
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
executable_path = {'executable_path': '../chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Get list of countries with overseas military bases

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_with_overseas_military_bases"
countries = []
browser.visit(url)
soup = bs(browser.html, 'html.parser')

country = []
for span in soup.find_all('span',class_='flagicon'):
    country.append(span.parent.parent.find_previous('h2').find_next('span').text)
    
country.pop()
country
# Out:
# ['Australia',
#  'Australia',
#  'China',
#  'China',
#  'China',
#  'China',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Greece',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Iran',
#  'Iran',
#  'Iran',
#  'Iran',
#  'Israel',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Japan',
#  'Pakistan',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Singapore',
#  'Singapore',
#  'Singapore',
#  'Singapore',
#  'Turkey',
#  'Turkey',
#  'Turkey',
#  'Turkey',
#  'Turkey',
#  'Turkey',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States']

# %% [markdown]
# ### Get list of countries where the bases are located

# %%
base = []
for i in range(1,18):
    list_of_lis = soup.find_all('span', class_='mw-headline')[i].parent.find_next('ul').find_all('li')
    for li in list_of_lis:
        base.append(li.next.find_next('a').text)

base.pop(56)
base.append('Tunisia')
base.append('Turkey')
base.append('United Arab Emirates')
base.append('United Kingdom')
base[56] = 'Qatar'
base.insert(57,'Somalia')
base.insert(58,'Syria')
base
# Out:
# ['Malaysia',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Cambodia',
#  'Djibouti',
#  'Tajikistan',
#  'Chad',
#  'Djibouti',
#  'Gabon',
#  'Germany',
#  'Ivory Coast',
#  'Lebanon',
#  'Niger',
#  'Senegal',
#  'Syria',
#  'United Arab Emirates',
#  'France',
#  'United States',
#  'Canada',
#  'Cyprus',
#  'Bhutan',
#  'Maldives',
#  'Madagascar',
#  'Mauritius',
#  'Nepal',
#  'Seychelles',
#  'Tajikistan',
#  'Syria',
#  'Eritrea',
#  'Iraq',
#  'Lebanon',
#  'Eritrea',
#  'United Arab Emirates',
#  'Djibouti',
#  'Afghanistan',
#  'Kuwait',
#  'Libya',
#  'United States',
#  'Djibouti',
#  'Saudi Arabia',
#  'Armenia',
#  'Belarus',
#  'Georgia',
#  'Kazakhstan',
#  'Kyrgyzstan',
#  'Moldova',
#  'Syria',
#  'Tajikistan',
#  'Ukraine',
#  'Australia',
#  'France',
#  'New Zealand',
#  'United States',
#  'Azerbaijan',
#  'Northern Cyprus',
#  'Iraq',
#  'Qatar',
#  'Somalia',
#  'Syria',
#  'Eritrea',
#  'Libya',
#  'Somaliland',
#  'Yemen',
#  'Bahrain',
#  'Belize',
#  'Brunei',
#  'Canada',
#  'Republic of Cyprus',
#  'Germany',
#  'Kenya',
#  'Nepal',
#  'Norway',
#  'Singapore',
#  'Qatar',
#  'Oman',
#  'United Arab Emirates',
#  'United States',
#  'Afghanistan',
#  'Australia',
#  'Bahrain',
#  'Belgium',
#  'Brazil',
#  'British Indian Ocean Territory',
#  'Bulgaria',
#  'Cuba',
#  'Cameroon',
#  'Curaçao',
#  'Djibouti',
#  'Germany',
#  'Greece',
#  'Greenland',
#  'Honduras',
#  'Iceland',
#  'Iraq',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kosovo',
#  'Kuwait',
#  'Netherlands',
#  'Niger',
#  'Norway',
#  'Oman',
#  'Philippines',
#  'Portugal',
#  'Qatar',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Syria',
#  'Tunisia',
#  'Turkey',
#  'United Arab Emirates',
#  'United Kingdom']

# %% [markdown]
# ### Make a dataframe of two scraped lists

# %%
military_base_df = pd.DataFrame(list(zip(country,base)),columns=['Country','Overseas Base'])
military_base_df
# Out:
#            Country         Overseas Base
# 0        Australia              Malaysia
# 1        Australia  United Arab Emirates
# 2            China           Afghanistan
# 3            China              Cambodia
# 4            China              Djibouti
# 5            China            Tajikistan
# 6           France                  Chad
# 7           France              Djibouti
# 8           France                 Gabon
# 9           France               Germany
# 10          France           Ivory Coast
# 11          France               Lebanon
# 12          France                 Niger
# 13          France               Senegal
# 14          France                 Syria
# 15          France  United Arab Emirates
# 16         Germany                France
# 17         Germany         United States
# 18         Germany                Canada
# 19          Greece                Cyprus
# 20           India                Bhutan
# 21           India              Maldives
# 22           India            Madagascar
# 23           India             Mauritius
# 24           India                 Nepal
# 25           India            Seychelles
# 26           India            Tajikistan
# 27            Iran                 Syria
# 28            Iran               Eritrea
# 29            Iran                  Iraq
# ..             ...                   ...
# 85   United States              Cameroon
# 86   United States               Curaçao
# 87   United States              Djibouti
# 88   United States               Germany
# 89   United States                Greece
# 90   United States             Greenland
# 91   United States              Honduras
# 92   United States               Iceland
# 93   United States                  Iraq
# 94   United States                Israel
# 95   United States                 Italy
# 96   United States                 Japan
# 97   United States                Kosovo
# 98   United States                Kuwait
# 99   United States           Netherlands
# 100  United States                 Niger
# 101  United States                Norway
# 102  United States                  Oman
# 103  United States           Philippines
# 104  United States              Portugal
# 105  United States                 Qatar
# 106  United States          Saudi Arabia
# 107  United States             Singapore
# 108  United States           South Korea
# 109  United States                 Spain
# 110  United States                 Syria
# 111  United States               Tunisia
# 112  United States                Turkey
# 113  United States  United Arab Emirates
# 114  United States        United Kingdom
#
# [115 rows x 2 columns]

# %% [markdown]
# ### Check the count of overseas bases for each country for correctness

# %%
military_base_df.groupby('Country').nunique()
# Out:
#                       Country  Overseas Base
# Country
# Australia                   1              2
# China                       1              4
# France                      1             10
# Germany                     1              3
# Greece                      1              1
# India                       1              7
# Iran                        1              4
# Israel                      1              1
# Italy                       1              6
# Japan                       1              1
# Pakistan                    1              1
# Russia                      1              9
# Singapore                   1              4
# Turkey                      1              6
# United Arab Emirates        1              4
# United Kingdom              1             14
# United States               1             38

# %%
military_base_df.to_csv('military_bases.csv')
